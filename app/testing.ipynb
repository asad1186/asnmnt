# %%
print('hi')
# Out:
# hi

# %%
from app.llm_client import OpenAIClient
from app.agent import AIAgent
from app.tools import retrieve_docs
from app.memory import SessionMemory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from llm_client import OpenAIClient
# ----> 2 from agent import AIAgent
#       3 from tools import retrieve_docs
#       4 from memory import SessionMemory
#
# File c:\Users\waris\Desktop\asnmnt\app\agent.py:1
# ----> 1 from app.prompts import AGENT_SYSTEM_PROMPT
#       3 class AIAgent:
#       4     def __init__(self, llm_client, tools, memory):
#
# ModuleNotFoundError: No module named 'app'

# %%
# Setup
llm = OpenAIClient()
memory = SessionMemory()
tools = {"retrieve_docs": retrieve_docs}
agent = AIAgent(llm, tools, memory)
